# %% [markdown]
# #PRÁCTICA 6

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
DIR_TEMP = '/content/drive/MyDrive/Colab Notebooks/precios_coches2.csv'

# %% [markdown]
# ###MOSTRAR LAS 5 PRIMERAS Y LAS 5 ÚLTIMAS FILAS

# %%
df= pd.read_csv(DIR_TEMP)

# %%
print('Las 5 primeras filas')
df.head(5)
# Out:
# Las 5 primeras filas
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
# ...

# %%
print('Las últimas 5 filas')
df.tail(5)
# Out:
# Las últimas 5 filas
#      car_ID  symboling          CarName fueltype aspiration doornumber  \
# 208     201         -1  volvo 145e (sw)      gas        std       four
# 209     202         -1      volvo 144ea      gas      turbo       four
# 210     203         -1      volvo 244dl      gas        std       four
# 211     204         -1        volvo 246   diesel      turbo       four
# 212     205         -1      volvo 264gl      gas      turbo       four
#
#     carbody drivewheel enginelocation  wheelbase  ...  enginesize  fuelsystem  \
# 208   sedan        rwd          front      109.1  ...         141        mpfi
# 209   sedan        rwd          front      109.1  ...         141        mpfi
# 210   sedan        rwd          front      109.1  ...         173        mpfi
# 211   sedan        rwd          front      109.1  ...         145         idi
# 212   sedan        rwd          front      109.1  ...         141        mpfi
#
# ...

# %% [markdown]
# ##**5)** Dimensiones del dataframe e información ofrecida por info y describe

# %%
print('Las dimensiones del Dataframe son:', df.shape,"\n")
print('La información proporcionada por info()')
df.info()# número de filas, número de columnas, índices, tipos de columnas y memoria usada
print('La información proporcionada por describe()')
df.describe()#media, mediana, máximo, mínimo, std (desviación estándar) y conteos
# Out:
# Las dimensiones del Dataframe son: (213, 26)
#
# La información proporcionada por info()
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 213 entries, 0 to 212
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            213 non-null    int64
#  1   symboling         213 non-null    int64
#  2   CarName           213 non-null    object
#  3   fueltype          213 non-null    object
#  4   aspiration        213 non-null    object
#  5   doornumber        213 non-null    object
#  6   carbody           213 non-null    object
#  7   drivewheel        213 non-null    object
#  8   enginelocation    213 non-null    object
#  9   wheelbase         213 non-null    float64
#  10  carlength         213 non-null    float64
#  11  carwidth          213 non-null    float64
#  12  carheight         213 non-null    float64
#  13  curbweight        213 non-null    int64
# ...

# %% [markdown]
# ##**6)** Insertar la columna Company. Mostrar las 3 primeras filas del DataFrame

# %%
Company= df['CarName'].apply (lambda x : x.split(" ")[0])#revisar funcionamiento del código
df.insert(2, "Company", Company)
print('Las 3 primeras filas del DataFrame son:')
df.head(3)
# Out:
# Las 3 primeras filas del DataFrame son:
#    car_ID  symboling      Company                   CarName fueltype  \
# 0       1          3  alfa-romero        alfa-romero giulia      gas
# 1       2          3  alfa-romero       alfa-romero stelvio      gas
# 2       3          1  alfa-romero  alfa-romero Quadrifoglio      gas
#
#   aspiration doornumber      carbody drivewheel enginelocation  ...  \
# 0        std        two  convertible        rwd          front  ...
# 1        std        two  convertible        rwd          front  ...
# 2        std        two    hatchback        rwd          front  ...
#
#    enginesize  fuelsystem  boreratio  stroke  compressionratio horsepower  \
# 0         130        mpfi       3.47    2.68                 9        111
# 1         130        mpfi       3.47    2.68                 9        111
# 2         152        mpfi       2.68    3.47                 9        154
#
#   peakrpm citympg highwaympg    price
# ...

# %%
print('Las 3 primeras filas del DataFrame son:')
df.head(3)
# Out:
# Las 3 primeras filas del DataFrame son:
#    car_ID  symboling      Company                   CarName fueltype  \
# 0       1          3  alfa-romero        alfa-romero giulia      gas
# 1       2          3  alfa-romero       alfa-romero stelvio      gas
# 2       3          1  alfa-romero  alfa-romero Quadrifoglio      gas
#
#   aspiration doornumber      carbody drivewheel enginelocation  ...  \
# 0        std        two  convertible        rwd          front  ...
# 1        std        two  convertible        rwd          front  ...
# 2        std        two    hatchback        rwd          front  ...
#
#    enginesize  fuelsystem  boreratio  stroke  compressionratio horsepower  \
# 0         130        mpfi       3.47    2.68                 9        111
# 1         130        mpfi       3.47    2.68                 9        111
# 2         152        mpfi       2.68    3.47                 9        154
#
#   peakrpm citympg highwaympg    price
# ...

# %% [markdown]
# ##**7)** Eliminar la columna CarName, car_Id y symboling. Compruebalo mostrando las tres primeras filas

# %%
del df['CarName']#solo funciona una vez
del df['car_ID']
del df['symboling']
print('Se muestra la tabla modificada')
df.head(3)
# Out:
# Se muestra la tabla modificada
#        Company fueltype aspiration doornumber      carbody drivewheel  \
# 0  alfa-romero      gas        std        two  convertible        rwd
# 1  alfa-romero      gas        std        two  convertible        rwd
# 2  alfa-romero      gas        std        two    hatchback        rwd
#
#   enginelocation  wheelbase  carlength  carwidth  ...  enginesize  fuelsystem  \
# 0          front       88.6      168.8      64.1  ...         130        mpfi
# 1          front       88.6      168.8      64.1  ...         130        mpfi
# 2          front       94.5      171.2      65.5  ...         152        mpfi
#
#   boreratio stroke compressionratio horsepower  peakrpm  citympg highwaympg  \
# 0      3.47   2.68                9        111        ?       21         27
# 1      3.47   2.68                9        111     5000       21         27
# 2      2.68   3.47                9        154     5000       19         26
#
#      price
# 0  13495.0
# ...

# %% [markdown]
# ##**8)** Mostrar todos los nombres de las compañías sin repetidos. Comprobar si aparecen repetidos por mayúscula-minúscula o fallos de deletro

# %%
print('Mostramos los nombres de compañía sin repetidos:')#aparecen los fallos que pide comprobar
df['Company'].unique()
# Out:
# Mostramos los nombres de compañía sin repetidos:
# array(['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#        'isuzu', 'jaguar', 'maxda', 'mazda', 'buick', 'mercury',
#        'mitsubishi', 'Nissan', 'nissan', 'peugeot', 'plymouth', 'porsche',
#        'porcshce', 'renault', 'saab', 'subaru', 'toyota', 'toyouta',
#        'vokswagen', 'volkswagen', 'vw', 'volvo'], dtype=object)

# %% [markdown]
# ##**9)** Convertir en minúsculas los nombres del fabricante con str.lower

# %%
print('Pasamos los nombres a letras minúsculas y mostramos los que no se repiten:')
df2=df.Company.str.lower()
df2.unique()
# Out:
# Pasamos los nombres a letras minúsculas y mostramos los que no se repiten:
# array(['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#        'isuzu', 'jaguar', 'maxda', 'mazda', 'buick', 'mercury',
#        'mitsubishi', 'nissan', 'peugeot', 'plymouth', 'porsche',
#        'porcshce', 'renault', 'saab', 'subaru', 'toyota', 'toyouta',
#        'vokswagen', 'volkswagen', 'vw', 'volvo'], dtype=object)

# %% [markdown]
# ##**10)** Reemplazar los nombres del ejercicio

# %%
df2=df2.replace('alfa-romero','alfa romero')
df2=df2.replace(['maxda'],'mazda')
df2=df2.replace(['vw'],'volkswagen')
df2=df2.replace(['porcshce'],'porsche')
df2=df2.replace(['toyouta'],'toyota')
print('Una vez solucionados los errores de escritura, las compañias cque dispone la tabla son:')
df2.unique()
# Out:
# Una vez solucionados los errores de escritura, las compañias cque dispone la tabla son:
# array(['alfa romero', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#        'isuzu', 'jaguar', 'mazda', 'buick', 'mercury', 'mitsubishi',
#        'nissan', 'peugeot', 'plymouth', 'porsche', 'renault', 'saab',
#        'subaru', 'toyota', 'vokswagen', 'volkswagen', 'volvo'],
#       dtype=object)

# %% [markdown]
# ##**11)** Mostrar cuantos coches de cada compañía

# %%
print('El número de coche de cada compañia es:')
df2.value_counts()
# Out:
# El número de coche de cada compañia es:
# toyota         32
# volkswagen     18
# nissan         18
# mazda          17
# mitsubishi     13
# honda          13
# subaru         12
# peugeot        11
# volvo          11
# dodge           9
# buick           8
# bmw             8
# audi            7
# plymouth        7
# saab            6
# porsche         5
# isuzu           4
# jaguar          3
# chevrolet       3
# alfa romero     3
# renault         2
# vokswagen       2
# mercury         1
# Name: Company, dtype: int64

# %% [markdown]
# ##**12)** Mostrar los nombres de todas las columnas

# %%
print('El nombre de las columnas de nuestra base de datos:')
df.columns
# Out:
# El nombre de las columnas de nuestra base de datos:
# Index(['Company', 'fueltype', 'aspiration', 'doornumber', 'carbody',
#        'drivewheel', 'enginelocation', 'wheelbase', 'carlength', 'carwidth',
#        'carheight', 'curbweight', 'enginetype', 'cylindernumber', 'enginesize',
#        'fuelsystem', 'boreratio', 'stroke', 'compressionratio', 'horsepower',
#        'peakrpm', 'citympg', 'highwaympg', 'price'],
#       dtype='object')

# %% [markdown]
# ##**13)** Nombre de cada columna, tipo y valores que contiene

# %%
for a in df:
  print(a)
  print(type(a))
  print(df[a])
# Out:
# Company
# <class 'str'>
# 0      alfa-romero
# 1      alfa-romero
# 2      alfa-romero
# 3             audi
# 4             audi
#           ...
# 208          volvo
# 209          volvo
# 210          volvo
# 211          volvo
# 212          volvo
# Name: Company, Length: 213, dtype: object
# fueltype
# <class 'str'>
# 0         gas
# 1         gas
# 2         gas
# 3         gas
# 4         gas
#         ...
# 208       gas
# 209       gas
# 210       gas
# 211    diesel
# 212       gas
# Name: fueltype, Length: 213, dtype: object
# aspiration
# <class 'str'>
# 0        std
# 1        std
# 2        std
# 3        std
# 4        std
#        ...
# 208      std
# 209    turbo
# 210      std
# 211    turbo
# 212    turbo
# Name: aspiration, Length: 213, dtype: object
# doornumber
# <class 'str'>
# 0       two
# 1       two
# 2       two
# 3      four
# 4      four
#        ...
# 208    four
# 209    four
# 210    four
# 211    four
# 212    four
# ...

# %% [markdown]
# ##**14)** LIMPIEDA DE DATOS Y ACTUALIZACIÓN DE FICHERO

# %%
print('El número de veces que se repite el ? es')
s=df.isnull().sum().sum()#me suma por columnas y luego por filas para darme el total
print(s)
# Out:
# El número de veces que se repite el ? es
# 0
